# %%
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# %%
traffic_vol = pd.read_csv("Traffic_Volume_Counts_2014-2018_.csv")

# %%
traffic_vol.head()
# Out:
#    ID  Segment ID            Roadway Name             From                To  \
# 0   2       70376                3 Avenue  East 154 Street   East 155 Street
# 1   2       70376                3 Avenue  East 155 Street   East 154 Street
# 2  56      176365  Bedford Park Boulevard  Grand Concourse  Valentine Avenue
# 3  56      176365  Bedford Park Boulevard  Grand Concourse  Valentine Avenue
# 4  62      147673                Broadway  West 242 Street        240 Street
#
#   Direction        Date  12:00-1:00 AM  1:00-2:00AM  2:00-3:00AM  \
# 0        NB  09/13/2014          204.0        177.0        133.0
# 1        SB  09/13/2014          140.0         51.0        128.0
# 2        EB  09/13/2014           94.0         73.0         65.0
# 3        WB  09/13/2014           88.0         82.0         75.0
# 4        SB  09/13/2014          255.0        209.0        149.0
#
#        ...        2:00-3:00PM  3:00-4:00PM  4:00-5:00PM  5:00-6:00PM  \
# ...

# %%
accidents = pd.read_csv("NYPD_Motor_Vehicle_Collisions.csv")
# Out:
# /Users/rgalowich/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
accidents.head()
# Out:
#          DATE  TIME   BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0  05/14/2019  0:00     BRONX    10459  40.817574 -73.896240
# 1  05/14/2019  0:00  BROOKLYN    11208  40.679863 -73.878000
# 2  05/14/2019  0:00  BROOKLYN    11234  40.611336 -73.921814
# 3  05/14/2019  0:00    QUEENS    11369  40.770332 -73.876080
# 4  05/14/2019  0:00       NaN      NaN  40.802372 -73.964310
#
#                   LOCATION                    ON STREET NAME  \
# 0   (40.817574, -73.89624)                               NaN
# 1     (40.679863, -73.878)                               NaN
# 2  (40.611336, -73.921814)                               NaN
# 3   (40.770332, -73.87608)  94 STREET
# 4   (40.802372, -73.96431)  AMSTERDAM AVENUE
#
#    CROSS STREET NAME                           OFF STREET NAME  \
# 0                NaN  830       FOX STREET
# 1                NaN  3183      ATLANTIC AVENUE
# 2                NaN  2067      EAST 53 PLACE
# ...
